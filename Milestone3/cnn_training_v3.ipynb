# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/MusicProject/Processed
# Out:
# label_map.json	X.npy  y.npy

# %%
import numpy as np

X = np.load('/content/drive/MyDrive/MusicProject/Processed/X.npy')
y = np.load('/content/drive/MyDrive/MusicProject/Processed/y.npy')

print(X.shape)
print(y.shape)
# Out:
# (5600, 128, 128)
# (5600,)

# %%
# Right now, X looks like this:
# (number_of_samples, height, width)
# Example: (5600, 128, 128)

# CNNs don't like "flat images".
# They expect a channel dimension, just like:
# - RGB images → 3 channels
# - Grayscale images → 1 channel

# Our spectrograms are grayscale,
# so we manually add a "1" channel at the end.

X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)

# Always print shape after reshaping.
# This is a sanity check to make sure nothing broke.
print("New X shape:", X.shape)
# Out:
# New X shape: (5600, 128, 128, 1)

# %%
# Right now, y contains labels like:
# "Guitar", "Flute", "Bass", etc.

# Neural networks DO NOT understand text.
# They only understand numbers.

# LabelEncoder converts each instrument name
# into a unique integer.
# Example:
# Guitar → 3
# Flute  → 1
# Bass   → 0

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# Fit = learn all unique labels
# Transform = convert labels to numbers
y_encoded = encoder.fit_transform(y)

# Print the mapping so we KNOW what number means what
print("Instrument classes (label order):")
print(encoder.classes_)

print("Encoded labels shape:", y_encoded.shape)
# Out:
# Instrument classes (label order):
# [0 1 2 3 4 5 6 7]
# Encoded labels shape: (5600,)

# %%
# If we train and test on the same data,
# the model might just MEMORIZE instead of LEARN.

# So we hide 20% of the data from the model.
# This hidden data is called the validation set.

from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X,
    y_encoded,
    test_size=0.2,      # 20% for validation
    random_state=42,    # makes results reproducible
    stratify=y_encoded  # keeps class balance intact
)

# Print shapes to verify split worked correctly
print("Training data shape:", X_train.shape, y_train.shape)
print("Validation data shape:", X_val.shape, y_val.shape)
# Out:
# Training data shape: (4480, 128, 128, 1) (4480,)
# Validation data shape: (1120, 128, 128, 1) (1120,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# CNN v3 — deeper model to increase accuracy
model = Sequential()

model.add(Input(shape=(128, 128, 1)))

# Conv block 1
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Conv block 2
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Conv block 3 (NEW — this is the upgrade)
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(len(set(y_encoded)), activation='softmax'))

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     6,422,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,517,512 (24.86 MB)
#  Trainable params: 6,517,512 (24.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np

print("Unique labels:", np.unique(y_encoded))
print("Label counts:", np.bincount(y_encoded))
# Out:
# Unique labels: [0 1 2 3 4 5 6 7]
# Label counts: [700 700 700 700 700 700 700 700]

# %%
print("X dtype:", X.dtype)
print("X min:", X.min())
print("X max:", X.max())
# Out:
# X dtype: float32
# X min: -80.0
# X max: 0.0

# %%
# Normalize log-mel spectrograms from [-80, 0] → [0, 1]
X = (X + 80.0) / 80.0

print("After normalization:")
print("X min:", X.min())
print("X max:", X.max())
# Out:
# After normalization:
# X min: 0.0
# X max: 1.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (4480, 128, 128, 1) (4480,)
# (1120, 128, 128, 1) (1120,)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_test = model.fit(
    X_train, y_train,
    epochs=5,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9923 - loss: 0.0376 - val_accuracy: 0.9250 - val_loss: 0.5405
# Epoch 2/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9927 - loss: 0.0236 - val_accuracy: 0.9321 - val_loss: 0.4990
# Epoch 3/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9896 - loss: 0.0276 - val_accuracy: 0.9214 - val_loss: 0.5577
# Epoch 4/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9887 - loss: 0.0328 - val_accuracy: 0.9152 - val_loss: 0.5259
# Epoch 5/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9880 - loss: 0.0447 - val_accuracy: 0.9223 - val_loss: 0.5313

# %%
history_v3 = model.fit(
    X_train, y_train,
    epochs=25,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9902 - loss: 0.0278 - val_accuracy: 0.9062 - val_loss: 0.5869
# Epoch 2/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9919 - loss: 0.0239 - val_accuracy: 0.9196 - val_loss: 0.5048
# Epoch 3/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9921 - loss: 0.0258 - val_accuracy: 0.9116 - val_loss: 0.5487
# Epoch 4/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9858 - loss: 0.0496 - val_accuracy: 0.9232 - val_loss: 0.5407
# Epoch 5/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9939 - loss: 0.0229 - val_accuracy: 0.9268 - val_loss: 0.5315
# Epoch 6/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9905 - loss: 0.0271 - val_accuracy: 0.9161 - val_loss: 0.7017
# Epoch 7/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9855 - loss: 0.0477 - val_accuracy: 0.9250 - val_loss: 0.4374
# Epoch 8/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9907 - loss: 0.0296 - val_accuracy: 0.9214 - val_loss: 0.4967
# Epoch 9/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9950 - loss: 0.0174 - val_accuracy: 0.9089 - val_loss: 0.5888
# Epoch 10/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9869 - loss: 0.0363 - val_accuracy: 0.9232 - val_loss: 0.5680
# Epoch 11/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9947 - loss: 0.0127 - val_accuracy: 0.9321 - val_loss: 0.5686
# Epoch 12/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9957 - loss: 0.0112 - val_accuracy: 0.9107 - val_loss: 0.5924
# Epoch 13/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9940 - loss: 0.0129 - val_accuracy: 0.9223 - val_loss: 0.6204
# Epoch 14/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9917 - loss: 0.0241 - val_accuracy: 0.9107 - val_loss: 0.6342
# Epoch 15/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9897 - loss: 0.0293 - val_accuracy: 0.9196 - val_loss: 0.6047
# Epoch 16/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9975 - loss: 0.0094 - val_accuracy: 0.9170 - val_loss: 0.6945
# Epoch 17/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9886 - loss: 0.0368 - val_accuracy: 0.9250 - val_loss: 0.6532
# Epoch 18/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9840 - loss: 0.0637 - val_accuracy: 0.9196 - val_loss: 0.6560
# Epoch 19/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9933 - loss: 0.0232 - val_accuracy: 0.9277 - val_loss: 0.5330
# Epoch 20/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9923 - loss: 0.0197 - val_accuracy: 0.9250 - val_loss: 0.5950
# Epoch 21/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9949 - loss: 0.0192 - val_accuracy: 0.9286 - val_loss: 0.5362
# Epoch 22/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9903 - loss: 0.0314 - val_accuracy: 0.9196 - val_loss: 0.6057
# Epoch 23/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9931 - loss: 0.0272 - val_accuracy: 0.9223 - val_loss: 0.4318
# Epoch 24/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9926 - loss: 0.0232 - val_accuracy: 0.9098 - val_loss: 0.6575
# Epoch 25/25
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9881 - loss: 0.0340 - val_accuracy: 0.9277 - val_loss: 0.5402

# %%
model.save("instrunet_model_v3.keras")

# %%
# !mv instrunet_model_v3.keras /content/drive/MyDrive/MusicProject/

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history_v3.history['accuracy'], label='Train Acc')
plt.plot(history_v3.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("CNN v3 Accuracy")
plt.show()

plt.figure()
plt.plot(history_v3.history['loss'], label='Train Loss')
plt.plot(history_v3.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("CNN v3 Loss")
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_val)
y_pred_cls = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_val, y_pred_cls)

disp = ConfusionMatrixDisplay(cm, display_labels=encoder.classes_)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("CNN v3 Confusion Matrix")
plt.show()
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
import numpy as np

# Predict class probabilities
y_pred_probs = model.predict(X_val)

# Convert probabilities to class indices
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
from sklearn.metrics import classification_report
import numpy as np

# Explicit class names in the correct order
instrument_names = [
    "brass",
    "flute",
    "guitar",
    "keyboard",
    "mallet",
    "reed",
    "string",
    "vocal"
]

# Generate predictions (if not already done)
y_pred_probs = model.predict(X_val)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification report with correct class names
report = classification_report(
    y_val,
    y_pred,
    target_names=instrument_names
)

print(report)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#               precision    recall  f1-score   support
#
#        brass       0.93      0.96      0.95       140
#        flute       0.91      0.91      0.91       140
#       guitar       0.92      0.96      0.94       140
#     keyboard       0.94      0.91      0.93       140
#       mallet       0.92      0.85      0.88       140
#         reed       0.86      0.89      0.87       140
#       string       0.94      0.92      0.93       140
#        vocal       0.99      1.00      1.00       140
#
#     accuracy                           0.93      1120
#    macro avg       0.93      0.93      0.93      1120
# weighted avg       0.93      0.93      0.93      1120

# %%
with open("classification_report_v3.txt", "w") as f:
    f.write(report)

# %%
# !ls
# Out:
# classification_report_v3.txt  drive  sample_data
